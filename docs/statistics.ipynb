# %%
from slime_nlp.slime import Stat

# %%
stat = Stat(path_data="../dataset/interpret.csv", 
            features=["BigWords", ...], 
            rand_value=5000, 
            path_results="../dataset/stat_test.csv")

# %% [markdown]
# #### 5. $\mathtt{Stat().plot\_dist()}$:
# <font size=3>

# %%
stat.plot_dist(features=['BigWords'], path_plot=None)

# %% [markdown]
# #### 6. $\mathtt{Stat().plot\_scatter()}$
# <font size=3>

# %%
stat = Stat(path_data="../dataset/interpret.csv", 
            features=["BigWords", ...], 
            rand_value=10, 
            path_results=None)

# %% [raw]
# from pandas import read_csv
# stat.results = read_csv("../dataset/adress_analysis.csv")

# %%
stat.plot_scatter(path_plot=None)

# %% [markdown]
# #### 7. $\mathtt{Stat().plot\_bars()}$
# <font size=3>

# %%
stat.plot_bars(path_plot=None)
